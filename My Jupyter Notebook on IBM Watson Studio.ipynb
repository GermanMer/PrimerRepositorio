# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **German Mercader**
# Data Scientist

# %% [markdown]
# *I am interested in data science because I want to improve customer service and develop new products*

# %% [markdown]
# ### The following code ask for your name (in spanish) and then greet you (in spanish)

# %%
nombre=input('Cual es tu nombre?: ')
print('Hola',nombre)
# Out:
# Cual es tu nombre?: German
# Hola German

# %% [markdown]
# > This is blocked quotes

# %% [markdown]
# 1. This
# 2. is
# 3. a
# 4. numbered
# 5. list

# %% [markdown]
# This is an [hyperlink](www.ibm.com)
